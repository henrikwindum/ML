# %% [markdown]
# # PCA Home Assignment
# ## Christian Igel, 2021

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn import datasets

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load handwritten digits data:

# %%
digits = datasets.load_digits()
imshape = digits.images[0].shape  # The 2D image shape
X = digits.images.reshape(digits.images.shape[0],-1)  # Image

# %% [markdown]
# Do the PCA:

# %%
from sklearn.decomposition import PCA

pca = PCA().fit(X)

# %% [markdown]
# Find out if 10 components are enough to explain 80% of the variance:

# %%
import matplotlib.pyplot as plt 

eigenvalues = pca.explained_variance_

plot_eigenvalues = eigenvalues / sum(eigenvalues)

plt.plot(np.arange(0, 10), np.cumsum(plot_eigenvalues[:10]))
plt.ylabel('cumulitative sum')
plt.xlabel('amount of eigenvectors')
plt.grid()
plt.show()

# %% [markdown]
# Plot the eigenspectrum:

# %%
plt.plot(np.arange(0, 10), np.log(plot_eigenvalues[:10]))
plt.ylabel('eigenvalue (log-scale)')
plt.xlabel('number of eigenvector')
plt.title('Eigenspectrum')
plt.grid()
plt.show()

# %% [markdown]
# Plot "eigendigits":

# %%
eigendigits = pca.components_[:5]

fig, axs = plt.subplots(1, 5, sharey=True, figsize=(15, 15))

for i, digit in enumerate(eigendigits):
    digit = digit.reshape(imshape)
    axs[i].imshow(digit, cmap='gray')

plt.show()
